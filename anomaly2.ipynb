# %% [markdown]
# # Anomaly Detection 2 — Device load vs external temperature
# **Course:** Management and Analysis of Physics Datasets (MAPD - Part B)
# **Author:** Agostina Gonzati (Group 5)
# **Dataset:** Industrial Refrigeration Devices (Chillers / Heat Pumps)
#
# ---
#
# Goal: identify possible correlations between the loading percentage of the
# devices and the external temperature.
#
# | Variable | Meaning | Unit | Decimals |
# |---|---|---|---|
# | `S125` | Capacity Circuit 1 | % | 0 |
# | `S181` | Capacity Circuit 2 | % | 0 |
# | `S41`  | External temperature | °C | 1 |
#
# **Naming convention.** Every variable in this section is prefixed with `t2_`
# so the notebook can be merged with the other tasks without collisions. The
# only exceptions are `spark`, `access_key` and `secret_key`, which in the
# merged notebook must be defined **once** at the top and shared: this section
# neither creates its own SparkSession nor calls `spark.stop()` midway.
#
# **Decimal scaling.** Table 3 of the assignment specifies the number of
# implicit decimals for each variable. `S41` has 1 decimal, so a raw value of
# `153` means `15.3 °C` and must be divided by 10. `S125` and `S181` have 0
# decimals and are used as they are. Skipping this step inflates every
# temperature by a factor of ten and makes the analysis meaningless.
#
# **Methodological note.** The physical expectation is that load increases at
# *extreme* temperatures (both cold and hot) because the compressors have to
# work harder in either case. If the relationship is U-shaped, the Pearson
# coefficient can come out close to zero despite a strong association, since it
# only captures the linear component. The analysis therefore complements Pearson
# with the **mean load per temperature bin**, which also reveals non-monotonic
# relationships.

# %% [markdown]
# ## 1. Spark session setup

# %%
import os
import time
import statistics

from pyspark.sql import SparkSession
from pyspark.sql import functions as sf
from pyspark.sql import Window

import matplotlib
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Credentials come from environment variables (see Appendix A of the handout).
# Note: if the kernel was not started from a login shell, .bashrc is never
# sourced and getenv returns None. Export them manually in that case.
access_key = os.getenv("S3_ACCESS_KEY")
secret_key = os.getenv("S3_PRIVATE_KEY") or os.getenv("S3_SECRET_KEY")

print(f"Access key found: {access_key is not None}")
print(f"Secret key found: {secret_key is not None}")
# Out:
# Access key found: True
# Secret key found: True

# %%
spark = SparkSession.builder \
    .master("spark://master:7077") \
    .appName("AnomalyDetection2_LoadVsTemperature") \
    .config("spark.executor.memory", "1536m") \
    .config("spark.jars.packages",
            "org.apache.hadoop:hadoop-aws:3.4.1,org.apache.hadoop:hadoop-common:3.4.1") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "true") \
    .config("spark.hadoop.fs.s3a.aws.credentials.provider",
            "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") \
    .config("spark.hadoop.fs.s3a.access.key", access_key) \
    .config("spark.hadoop.fs.s3a.secret.key", secret_key) \
    .config("spark.hadoop.fs.s3a.endpoint", "https://cloud-areapd.pd.infn.it:5210") \
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
    .config("spark.hadoop.fs.s3a.metadatastore.impl",
            "org.apache.hadoop.fs.s3a.s3guard.NullMetadataStore") \
    .config("spark.hadoop.fs.s3a.path.style.access", "true") \
    .config("spark.hadoop.fs.s3a.connection.ssl.enabled", "false") \
    .getOrCreate()

spark.sparkContext.setLogLevel("WARN")

print(f"master:             {spark.sparkContext.master}")
print(f"defaultParallelism: {spark.sparkContext.defaultParallelism}")
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/usr/local/spark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /home/agonzati/.ivy2.5.2/cache
# The jars for the packages stored in: /home/agonzati/.ivy2.5.2/jars
# org.apache.hadoop#hadoop-aws added as a dependency
# org.apache.hadoop#hadoop-common added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-eea6f2e8-a60a-40f1-9858-08a03ae626e1;1.0
# 	confs: [default]
# 	found org.apache.hadoop#hadoop-aws;3.4.1 in central
# 	found software.amazon.awssdk#bundle;2.24.6 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.1.3.Final in central
# 	found org.apache.hadoop#hadoop-common;3.4.1 in central
# 	found org.apache.hadoop.thirdparty#hadoop-shaded-protobuf_3_25;1.3.0 in central
# 	found org.apache.hadoop#hadoop-annotations;3.4.1 in central
# 	found org.apache.hadoop.thirdparty#hadoop-shaded-guava;1.3.0 in central
# 	found com.google.guava#guava;27.0-jre in central
# 	found com.google.guava#failureaccess;1.0 in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found org.checkerframework#checker-qual;2.5.2 in central
# 	found com.google.j2objc#j2objc-annotations;1.1 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.17 in central
# 	found commons-cli#commons-cli;1.5.0 in central
# 	found org.apache.commons#commons-math3;3.6.1 in central
# 	found org.apache.httpcomponents#httpclient;4.5.13 in central
# 	found org.apache.httpcomponents#httpcore;4.4.13 in central
# 	found commons-logging#commons-logging;1.2 in central
# 	found commons-codec#commons-codec;1.15 in central
# 	found commons-io#commons-io;2.16.1 in central
# 	found commons-net#commons-net;3.9.0 in central
# 	found commons-collections#commons-collections;3.2.2 in central
# 	found javax.servlet#javax.servlet-api;3.1.0 in central
# 	found org.eclipse.jetty#jetty-server;9.4.53.v20231009 in central
# 	found org.eclipse.jetty#jetty-http;9.4.53.v20231009 in central
# 	found org.eclipse.jetty#jetty-util;9.4.53.v20231009 in central
# 	found org.eclipse.jetty#jetty-io;9.4.53.v20231009 in central
# 	found org.eclipse.jetty#jetty-servlet;9.4.53.v20231009 in central
# 	found org.eclipse.jetty#jetty-security;9.4.53.v20231009 in central
# 	found org.eclipse.jetty#jetty-util-ajax;9.4.53.v20231009 in central
# 	found org.eclipse.jetty#jetty-webapp;9.4.53.v20231009 in central
# 	found org.eclipse.jetty#jetty-xml;9.4.53.v20231009 in central
# 	found com.sun.jersey#jersey-core;1.19.4 in central
# 	found javax.ws.rs#jsr311-api;1.1.1 in central
# 	found com.sun.jersey#jersey-servlet;1.19.4 in central
# 	found com.sun.jersey#jersey-server;1.19.4 in central
# 	found com.github.pjfanning#jersey-json;1.22.0 in central
# 	found com.sun.xml.bind#jaxb-impl;2.2.3-1 in central
# 	found javax.xml.bind#jaxb-api;2.2.11 in central
# 	found org.codehaus.jettison#jettison;1.5.4 in central
# 	found ch.qos.reload4j#reload4j;1.2.22 in central
# 	found commons-beanutils#commons-beanutils;1.9.4 in central
# 	found org.apache.commons#commons-configuration2;2.10.1 in central
# 	found org.apache.commons#commons-lang3;3.12.0 in central
# 	found org.apache.commons#commons-text;1.10.0 in central
# 	found org.slf4j#slf4j-api;1.7.36 in central
# 	found org.slf4j#slf4j-reload4j;1.7.36 in central
# 	found org.apache.avro#avro;1.9.2 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.12.7 in central
# 	found com.fasterxml.jackson.core#jackson-databind;2.12.7.1 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.12.7 in central
# 	found org.apache.commons#commons-compress;1.26.1 in central
# 	found com.google.re2j#re2j;1.1 in central
# 	found com.google.code.gson#gson;2.9.0 in central
# 	found org.apache.hadoop#hadoop-auth;3.4.1 in central
# 	found com.nimbusds#nimbus-jose-jwt;9.37.2 in central
# 	found com.github.stephenc.jcip#jcip-annotations;1.0-1 in central
# 	found org.apache.zookeeper#zookeeper;3.8.4 in central
# 	found org.apache.zookeeper#zookeeper-jute;3.8.4 in central
# 	found org.apache.yetus#audience-annotations;0.12.0 in central
# 	found io.dropwizard.metrics#metrics-core;3.2.4 in central
# 	found org.apache.curator#curator-framework;5.2.0 in central
# 	found org.apache.curator#curator-client;5.2.0 in central
# 	found org.apache.kerby#kerb-core;2.0.3 in central
# 	found org.apache.kerby#kerby-pkix;2.0.3 in central
# 	found org.apache.kerby#kerby-asn1;2.0.3 in central
# 	found org.apache.kerby#kerby-util;2.0.3 in central
# 	found org.apache.kerby#kerb-util;2.0.3 in central
# 	found org.apache.kerby#kerby-config;2.0.3 in central
# 	found org.apache.kerby#kerb-crypto;2.0.3 in central
# 	found com.jcraft#jsch;0.1.55 in central
# 	found org.apache.curator#curator-recipes;5.2.0 in central
# 	found io.netty#netty-handler;4.1.100.Final in central
# 	found io.netty#netty-common;4.1.100.Final in central
# 	found io.netty#netty-resolver;4.1.100.Final in central
# 	found io.netty#netty-buffer;4.1.100.Final in central
# 	found io.netty#netty-transport;4.1.100.Final in central
# 	found io.netty#netty-transport-native-unix-common;4.1.100.Final in central
# 	found io.netty#netty-codec;4.1.100.Final in central
# 	found io.netty#netty-transport-native-epoll;4.1.100.Final in central
# 	found io.netty#netty-transport-classes-epoll;4.1.100.Final in central
# 	found org.bouncycastle#bcprov-jdk18on;1.78.1 in central
# 	found org.codehaus.woodstox#stax2-api;4.2.1 in central
# 	found com.fasterxml.woodstox#woodstox-core;5.4.0 in central
# 	found dnsjava#dnsjava;3.6.1 in central
# 	found org.xerial.snappy#snappy-java;1.1.10.4 in central
# 	found jakarta.activation#jakarta.activation-api;1.2.1 in central
# 	found javax.servlet.jsp#jsp-api;2.1 in central
# :: resolution report :: resolve 3023ms :: artifacts dl 99ms
# 	:: modules in use:
# 	ch.qos.reload4j#reload4j;1.2.22 from central in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.12.7 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.12.7 from central in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.12.7.1 from central in [default]
# 	com.fasterxml.woodstox#woodstox-core;5.4.0 from central in [default]
# 	com.github.pjfanning#jersey-json;1.22.0 from central in [default]
# 	com.github.stephenc.jcip#jcip-annotations;1.0-1 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.code.gson#gson;2.9.0 from central in [default]
# 	com.google.guava#failureaccess;1.0 from central in [default]
# 	com.google.guava#guava;27.0-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.1 from central in [default]
# 	com.google.re2j#re2j;1.1 from central in [default]
# 	com.jcraft#jsch;0.1.55 from central in [default]
# 	com.nimbusds#nimbus-jose-jwt;9.37.2 from central in [default]
# 	com.sun.jersey#jersey-core;1.19.4 from central in [default]
# 	com.sun.jersey#jersey-server;1.19.4 from central in [default]
# 	com.sun.jersey#jersey-servlet;1.19.4 from central in [default]
# 	com.sun.xml.bind#jaxb-impl;2.2.3-1 from central in [default]
# 	commons-beanutils#commons-beanutils;1.9.4 from central in [default]
# 	commons-cli#commons-cli;1.5.0 from central in [default]
# 	commons-codec#commons-codec;1.15 from central in [default]
# 	commons-collections#commons-collections;3.2.2 from central in [default]
# 	commons-io#commons-io;2.16.1 from central in [default]
# 	commons-logging#commons-logging;1.2 from central in [default]
# 	commons-net#commons-net;3.9.0 from central in [default]
# 	dnsjava#dnsjava;3.6.1 from central in [default]
# 	io.dropwizard.metrics#metrics-core;3.2.4 from central in [default]
# 	io.netty#netty-buffer;4.1.100.Final from central in [default]
# 	io.netty#netty-codec;4.1.100.Final from central in [default]
# 	io.netty#netty-common;4.1.100.Final from central in [default]
# 	io.netty#netty-handler;4.1.100.Final from central in [default]
# 	io.netty#netty-resolver;4.1.100.Final from central in [default]
# 	io.netty#netty-transport;4.1.100.Final from central in [default]
# 	io.netty#netty-transport-classes-epoll;4.1.100.Final from central in [default]
# 	io.netty#netty-transport-native-epoll;4.1.100.Final from central in [default]
# 	io.netty#netty-transport-native-unix-common;4.1.100.Final from central in [default]
# 	jakarta.activation#jakarta.activation-api;1.2.1 from central in [default]
# 	javax.servlet#javax.servlet-api;3.1.0 from central in [default]
# 	javax.servlet.jsp#jsp-api;2.1 from central in [default]
# 	javax.ws.rs#jsr311-api;1.1.1 from central in [default]
# 	javax.xml.bind#jaxb-api;2.2.11 from central in [default]
# 	org.apache.avro#avro;1.9.2 from central in [default]
# 	org.apache.commons#commons-compress;1.26.1 from central in [default]
# 	org.apache.commons#commons-configuration2;2.10.1 from central in [default]
# 	org.apache.commons#commons-lang3;3.12.0 from central in [default]
# 	org.apache.commons#commons-math3;3.6.1 from central in [default]
# 	org.apache.commons#commons-text;1.10.0 from central in [default]
# 	org.apache.curator#curator-client;5.2.0 from central in [default]
# 	org.apache.curator#curator-framework;5.2.0 from central in [default]
# 	org.apache.curator#curator-recipes;5.2.0 from central in [default]
# 	org.apache.hadoop#hadoop-annotations;3.4.1 from central in [default]
# 	org.apache.hadoop#hadoop-auth;3.4.1 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.4.1 from central in [default]
# 	org.apache.hadoop#hadoop-common;3.4.1 from central in [default]
# 	org.apache.hadoop.thirdparty#hadoop-shaded-guava;1.3.0 from central in [default]
# 	org.apache.hadoop.thirdparty#hadoop-shaded-protobuf_3_25;1.3.0 from central in [default]
# 	org.apache.httpcomponents#httpclient;4.5.13 from central in [default]
# 	org.apache.httpcomponents#httpcore;4.4.13 from central in [default]
# 	org.apache.kerby#kerb-core;2.0.3 from central in [default]
# 	org.apache.kerby#kerb-crypto;2.0.3 from central in [default]
# 	org.apache.kerby#kerb-util;2.0.3 from central in [default]
# 	org.apache.kerby#kerby-asn1;2.0.3 from central in [default]
# 	org.apache.kerby#kerby-config;2.0.3 from central in [default]
# 	org.apache.kerby#kerby-pkix;2.0.3 from central in [default]
# 	org.apache.kerby#kerby-util;2.0.3 from central in [default]
# 	org.apache.yetus#audience-annotations;0.12.0 from central in [default]
# 	org.apache.zookeeper#zookeeper;3.8.4 from central in [default]
# 	org.apache.zookeeper#zookeeper-jute;3.8.4 from central in [default]
# 	org.bouncycastle#bcprov-jdk18on;1.78.1 from central in [default]
# 	org.checkerframework#checker-qual;2.5.2 from central in [default]
# 	org.codehaus.jettison#jettison;1.5.4 from central in [default]
# 	org.codehaus.mojo#animal-sniffer-annotations;1.17 from central in [default]
# 	org.codehaus.woodstox#stax2-api;4.2.1 from central in [default]
# 	org.eclipse.jetty#jetty-http;9.4.53.v20231009 from central in [default]
# 	org.eclipse.jetty#jetty-io;9.4.53.v20231009 from central in [default]
# 	org.eclipse.jetty#jetty-security;9.4.53.v20231009 from central in [default]
# 	org.eclipse.jetty#jetty-server;9.4.53.v20231009 from central in [default]
# 	org.eclipse.jetty#jetty-servlet;9.4.53.v20231009 from central in [default]
# 	org.eclipse.jetty#jetty-util;9.4.53.v20231009 from central in [default]
# 	org.eclipse.jetty#jetty-util-ajax;9.4.53.v20231009 from central in [default]
# 	org.eclipse.jetty#jetty-webapp;9.4.53.v20231009 from central in [default]
# 	org.eclipse.jetty#jetty-xml;9.4.53.v20231009 from central in [default]
# 	org.slf4j#slf4j-api;1.7.36 from central in [default]
# 	org.slf4j#slf4j-reload4j;1.7.36 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.1.3.Final from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.10.4 from central in [default]
# 	software.amazon.awssdk#bundle;2.24.6 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   89  |   0   |   0   |   0   ||   89  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-eea6f2e8-a60a-40f1-9858-08a03ae626e1
# 	confs: [default]
# 	0 artifacts copied, 89 already retrieved (0kB/22ms)
# 26/09/13 15:48:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/09/13 15:48:13 WARN SparkConf: Note that spark.local.dir will be overridden by the value set by the cluster manager (via SPARK_LOCAL_DIRS in standalone/kubernetes and LOCAL_DIRS in YARN).
# master:             spark://master:7077
# defaultParallelism: 4

# %% [markdown]
# ## 2. Reading the data
#
# The raw dataset is in **long** format: one row per measurement of a single
# sensor (`when`, `hwid`, `metric`, `value`).

# %%
t2_DATA_PATH = "s3a://MAPDB-Group5/data_parquet"

t2_df_raw = spark.read.parquet(t2_DATA_PATH)
t2_df_raw.printSchema()
t2_df_raw.show(5, truncate=False)
# Out:
# root
#  |-- when: long (nullable = true)
#  |-- hwid: string (nullable = true)
#  |-- metric: string (nullable = true)
#  |-- value: integer (nullable = true)
# [Stage 1:>                                                          (0 + 1) / 1]
# +-------------+------+------+-----+
# |when         |hwid  |metric|value|
# +-------------+------+------+-----+
# |1604265597702|SW-115|S80   |0    |
# |1604265597702|SW-115|S73   |0    |
# |1604265597702|SW-115|S72   |100  |
# |1604265597702|SW-115|S71   |100  |
# |1604265597702|SW-115|P16   |200  |
# +-------------+------+------+-----+
# only showing top 5 rows

# %% [markdown]
# ## 3. Selecting the metrics of interest
#
# Filtering *before* anything else drastically reduces the volume to resample and
# to move across the network: out of the ~120 metrics in the dataset only three
# are needed here. It is a *narrow* transformation, so it costs no shuffle.

# %%
t2_LOAD_COLS = ["S125", "S181"]     # capacity of circuits 1 and 2, in %
t2_TEMP_COL  = "S41"                 # external temperature, in deg C
t2_TARGET    = t2_LOAD_COLS + [t2_TEMP_COL]

# Implicit decimals from Table 3 of the assignment: the raw integers must be
# divided by 10**decimals to recover the physical value.
t2_DECIMALS = {"S125": 0, "S181": 0, "S41": 1}

t2_df = t2_df_raw.where(sf.col("metric").isin(t2_TARGET))

# Which metrics actually exist, and for which devices
t2_df.groupBy("hwid", "metric").count().orderBy("hwid", "metric").show(20)
# Out:
# [Stage 2:==================================================>        (6 + 1) / 7]
# +------+------+------+
# |  hwid|metric| count|
# +------+------+------+
# |SW-065|  S125|211498|
# |SW-065|  S181|207560|
# |SW-065|   S41|211497|
# |SW-088|  S125|323040|
# |SW-088|  S181|316815|
# |SW-088|   S41|323041|
# |SW-106|  S125|200983|
# |SW-106|  S181|197046|
# |SW-106|   S41|200984|
# |SW-115|  S125|354781|
# |SW-115|  S181|348128|
# |SW-115|   S41|354779|
# +------+------+------+

# %% [markdown]
# ## 4. Resampling to 1 minute
#
# The sampling frequency ranges from 30 to 60 seconds, so it has to be
# normalised.
#
# The **mean** is the right aggregation. Averaging two readings of 43% and 57%
# within a minute gives 50%, the average capacity delivered in that minute,
# which is what we want to correlate with temperature. The maximum would give
# the peak reached instead.
#
# The assignment's min/max hint applies to variables like `S117`, which is 0 or
# 1 for "compressor off/on": there the average would mean "half on", which does
# not exist.

# %%
# "when" is a UNIX timestamp in milliseconds
t2_df = t2_df.withColumn("when", sf.timestamp_millis(sf.col("when")))

# Minute bucket: the common key across all metrics
t2_df = t2_df.withColumn("timestamp_bucket", sf.date_trunc("minute", sf.col("when")))

t2_df_resampled = (
    t2_df.groupBy("timestamp_bucket", "hwid", "metric")
         .agg(sf.mean("value").alias("value"))
)

t2_df_resampled.show(5, truncate=False)
# Out:
# [Stage 5:==================================================>        (6 + 1) / 7]
# +-------------------+------+------+-----+
# |timestamp_bucket   |hwid  |metric|value|
# +-------------------+------+------+-----+
# |2021-02-28 23:26:00|SW-088|S181  |0.0  |
# |2021-03-01 02:00:00|SW-088|S41   |91.0 |
# |2021-03-01 04:07:00|SW-088|S125  |66.0 |
# |2021-03-01 04:41:00|SW-088|S125  |66.0 |
# |2021-03-01 06:30:00|SW-088|S125  |66.0 |
# +-------------------+------+------+-----+
# only showing top 5 rows

# %% [markdown]
# ## 5. Pivot long → wide
#
# To correlate two variables they must sit **on the same row**. The `pivot` turns
# the values of the `metric` column into actual columns.
#
# Passing the explicit list of expected values spares Spark a preliminary job to
# discover them, so it is more efficient.

# %%
t2_df_wide = (
    t2_df_resampled.groupBy("timestamp_bucket", "hwid")
                   .pivot("metric", t2_TARGET)      # explicit list = faster
                   .agg(sf.first("value"))
)

# Apply the decimal scaling of Table 3. Without this step S41 is off by a
# factor of ten: a raw 153 would read as 153 deg C instead of 15.3 deg C.
for t2_c, t2_d in t2_DECIMALS.items():
    if t2_d > 0:
        t2_df_wide = t2_df_wide.withColumn(t2_c, sf.col(t2_c) / (10 ** t2_d))

t2_df_wide = t2_df_wide.cache()
t2_n_rows = t2_df_wide.count()
print(f"Rows (device x minute): {t2_n_rows:,}")
t2_df_wide.show(5)
# Out:
# Rows (device x minute): 671,851
# +-------------------+------+-----+-----+-----+
# |   timestamp_bucket|  hwid| S125| S181|  S41|
# +-------------------+------+-----+-----+-----+
# |2021-03-05 03:08:00|SW-088|  0.0|  0.0| 12.7|
# |2020-12-15 08:07:00|SW-115| 57.0| 43.0|  8.6|
# |2020-12-27 04:29:00|SW-115|100.0|100.0|  4.9|
# |2021-03-10 01:25:00|SW-106| 43.0|  0.0| 14.6|
# |2021-03-12 17:41:00|SW-106| 57.0|  0.0|14.95|
# +-------------------+------+-----+-----+-----+
# only showing top 5 rows

# %%
# Sanity check on the physical ranges: after scaling, the temperature must
# look like an outdoor temperature and the loads must lie within 0-100%.
t2_df_wide.select(
    sf.min(t2_TEMP_COL).alias("temp_min"), sf.max(t2_TEMP_COL).alias("temp_max"),
    sf.min("S125").alias("S125_min"),      sf.max("S125").alias("S125_max"),
    sf.min("S181").alias("S181_min"),      sf.max("S181").alias("S181_max"),
    sf.min("timestamp_bucket").alias("from"), sf.max("timestamp_bucket").alias("to"),
).show(truncate=False)
# Out:
# +--------+--------+--------+--------+--------+--------+-------------------+-------------------+
# |temp_min|temp_max|S125_min|S125_max|S181_min|S181_max|from               |to                 |
# +--------+--------+--------+--------+--------+--------+-------------------+-------------------+
# |-11.0   |34.0    |0.0     |100.0   |0.0     |100.0   |2020-10-01 00:00:00|2021-03-31 23:59:00|
# +--------+--------+--------+--------+--------+--------+-------------------+-------------------+

# %% [markdown]
# ### Variable coverage per device
#
# A device may have only circuit 1, only circuit 2, or both. Knowing which is the
# case matters before correlating: an entirely null column yields a `None`
# correlation, not a zero.

# %%
t2_coverage = t2_df_wide.groupBy("hwid").agg(
    sf.count("*").alias("n_minutes"),
    *[sf.count(c).alias(f"non_null_{c}") for c in t2_TARGET]
).orderBy("hwid")

t2_coverage.show()
t2_pdf_cov = t2_coverage.toPandas()
# Out:
# +------+---------+-------------+-------------+------------+
# |  hwid|n_minutes|non_null_S125|non_null_S181|non_null_S41|
# +------+---------+-------------+-------------+------------+
# |SW-065|   136288|       135219|       132608|      135218|
# |SW-088|   191997|       190827|       187038|      190827|
# |SW-106|   105879|       105684|       103636|      105684|
# |SW-115|   237687|       236532|       232120|      236531|
# +------+---------+-------------+-------------+------------+

# %% [markdown]
# All four devices carry both circuits, and both are populated for
# essentially every recorded minute (a reported zero means the circuit is present but idle,
# not that the circuit is missing). The assignment's caveat that "a device can
# have one or both of these variables" therefore does not bite on this sample,
# but the code handles the general case anyway, since a missing circuit must be
# treated as absent rather than as a circuit sitting at zero.

# %% [markdown]
# ## 6. Overall device load
#
# Beyond the two circuits taken separately, a synthetic load figure is useful.
# We use the **mean of the circuits that are actually present**: `S125` and
# `S181` are both percentages on the same scale, so their mean is directly
# interpretable. Where neither is present the result stays null.
# Averaging them equally is a simplification: it assumes the two circuits are
# the same size, which the dataset never states. The two circuits are looked at
# separately later on (section 10).

# %%
# coalesce(col, lit(0)) would replace nulls with zeros and bias the mean
# downwards: only the non-null circuits are counted instead.
t2_n_present = sum(sf.when(sf.col(c).isNotNull(), 1).otherwise(0) for c in t2_LOAD_COLS)
t2_sum_load  = sum(sf.coalesce(sf.col(c), sf.lit(0.0)) for c in t2_LOAD_COLS)

t2_df_wide = t2_df_wide.withColumn(
    "load_avg", sf.when(t2_n_present > 0, t2_sum_load / t2_n_present)
)

t2_df_wide.select("hwid", "timestamp_bucket", *t2_TARGET, "load_avg").show(5)
# Out:
# +------+-------------------+-----+-----+-----+--------+
# |  hwid|   timestamp_bucket| S125| S181|  S41|load_avg|
# +------+-------------------+-----+-----+-----+--------+
# |SW-088|2021-03-05 03:08:00|  0.0|  0.0| 12.7|     0.0|
# |SW-115|2020-12-15 08:07:00| 57.0| 43.0|  8.6|    50.0|
# |SW-115|2020-12-27 04:29:00|100.0|100.0|  4.9|   100.0|
# |SW-106|2021-03-10 01:25:00| 43.0|  0.0| 14.6|    21.5|
# |SW-106|2021-03-12 17:41:00| 57.0|  0.0|14.95|    28.5|
# +------+-------------------+-----+-----+-----+--------+
# only showing top 5 rows

# %% [markdown]
# Each row is one (device, minute) pair, five out of 671 851.
#
# `SW-115` has its two circuits at 57% and 43%, so they are controlled
# independently and `load_avg` averages them to 50%. Note that the 50% comes
# from averaging the two circuits, not from either sitting at a 50% level. Where
# values like 43% and 57% come from is what section 12 looks into.
#
# `SW-088` sits at zero on both circuits: idle. Those minutes are more than half
# the dataset.

# %% [markdown]
# ## 7. Hourly aggregation and idle periods
#
# Two methodological choices must be made **before** computing any correlation,
# because both change the result substantially.
#
# **Time granularity.** External temperature varies slowly, over hours; the
# compressor load fluctuates minute by minute following the control cycle.
# Correlating at minute level therefore feeds the computation a lot of
# high-frequency noise that temperature cannot possibly explain. Aggregating to
# the hour compares two quantities on the same time scale.
#
# **Idle periods.** When a device is off, `S125` and `S181` read 0. Including
# those minutes answers the question *"is the device running?"* rather than
# *"how hard is it working?"*: if idle stretches are long, they dominate the
# computation and flatten the correlation.
#
# Both questions are legitimate, but they must be kept apart. Below the
# correlation is computed on both sets and the results are compared.

# %%
# Hourly bin, same convention as Task 1
t2_df_wide = t2_df_wide.withColumn("hour_bin", sf.date_trunc("hour", sf.col("timestamp_bucket")))

t2_df_hourly = t2_df_wide.groupBy("hwid", "hour_bin").agg(
    *[sf.mean(c).alias(c) for c in t2_TARGET],
    sf.mean("load_avg").alias("load_avg"),
    # fraction of minutes in which the device was actually working
    sf.mean(sf.when(sf.col("load_avg") > 0, 1.0).otherwise(0.0)).alias("active_fraction"),
).cache()

print(f"Hourly rows: {t2_df_hourly.count():,}")
t2_df_hourly.show(5)
# Out:
# [Stage 63:=================================================>    (185 + 6) / 200]
# Hourly rows: 13,052
# +------+-------------------+------------------+------------------+------------------+------------------+--------------------+
# |  hwid|           hour_bin|              S125|              S181|               S41|          load_avg|     active_fraction|
# +------+-------------------+------------------+------------------+------------------+------------------+--------------------+
# |SW-088|2021-01-03 03:00:00|               0.0|               0.0|10.486607142857142|               0.0|                 0.0|
# |SW-115|2021-01-08 00:00:00| 2.111111111111111|               0.0|2.7472222222222222|1.0555555555555556|0.037037037037037035|
# |SW-115|2020-12-24 14:00:00|19.682692307692307| 32.91346153846154| 6.311538461538461|26.298076923076923|  0.8846153846153846|
# |SW-106|2021-03-25 00:00:00|              43.0|              43.0| 9.861538461538462|              43.0|                 1.0|
# |SW-115|2021-01-06 12:00:00|12.528301886792454|25.735849056603772|2.6292452830188684|19.132075471698112|  0.2830188679245283|
# +------+-------------------+------------------+------------------+------------------+------------------+--------------------+
# only showing top 5 rows

# %%
# How much do idle periods weigh?
t2_tot    = t2_df_wide.where(sf.col("load_avg").isNotNull()).count()
t2_idle   = t2_df_wide.where(sf.col("load_avg") == 0).count()

print(f"Minutes with known load: {t2_tot:,}")
print(f"Minutes at zero load:    {t2_idle:,}  ({100 * t2_idle / t2_tot:.1f}%)")
print(f"Minutes with load > 0:   {t2_tot - t2_idle:,}")
# Out:
# Minutes with known load: 671,850
# Minutes at zero load:    360,336  (53.6%)
# Minutes with load > 0:   311,514

# %% [markdown]
# Roughly **54% of the recorded minutes have zero load**: more than half the
# time, these machines are not running at all.
#
# That is expected of a thermal plant, it reaches its set-point and shuts off
# until the temperature drifts back, but it changes what a correlation computed
# on all rows actually measures. Including idle minutes answers "is the device
# running?"; excluding them answers "how hard is it working?". Both questions
# are legitimate and they have different answers, so from here on the two are
# kept apart rather than silently merged.

# %% [markdown]
# ## 8. Pearson correlation
#
# Pearson measures the strength of the **linear** relationship between two
# variables and ranges from -1 to +1. It is computed on three different sets, to
# see how much the answer depends on the choices made above:
#
# 1. minute-level data, all rows;
# 2. hourly data, all rows;
# 3. hourly data, active hours only.

# %%
def t2_pearson(df, label):
    """Pearson of each load variable against temperature."""
    print(f"--- {label} ---")
    out = {}
    for c in t2_LOAD_COLS + ["load_avg"]:
        try:
            r = df.stat.corr(c, t2_TEMP_COL)
        except Exception:
            r = None
        out[c] = r
        print(f"  {c:9s} vs {t2_TEMP_COL}: "
              + (f"{r:+.4f}" if r is not None else "not computable"))
    return out


t2_corr_min    = t2_pearson(t2_df_wide,   "minute level, all rows")
t2_corr_hour   = t2_pearson(t2_df_hourly, "hourly, all rows")
t2_corr_active = t2_pearson(t2_df_hourly.where(sf.col("load_avg") > 0),
                            "hourly, active hours only")
# Out:
# --- minute level, all rows ---
#   S125      vs S41: -0.1396
#   S181      vs S41: -0.0891
#   load_avg  vs S41: -0.1374
# --- hourly, all rows ---
#   S125      vs S41: -0.1751
#   S181      vs S41: -0.0965
#   load_avg  vs S41: -0.1569
# --- hourly, active hours only ---
#   S125      vs S41: -0.2379
#   S181      vs S41: -0.1046
#   load_avg  vs S41: -0.2125

# %%
# Compact comparison: is the result robust, or does it hinge on the choices?
t2_comparison = pd.DataFrame({
    "minute":        t2_corr_min,
    "hourly":        t2_corr_hour,
    "hourly active": t2_corr_active,
}).round(4)
t2_comparison
# Out:
#           minute  hourly  hourly active
# S125     -0.1396 -0.1751        -0.2379
# S181     -0.0891 -0.0965        -0.1046
# load_avg -0.1374 -0.1569        -0.2125

# %% [markdown]
# Rows are the load variables, columns the three datasets (minutes, hours,
# active minutes only). Data from the 4 devices are all pooled together.

# %% [markdown]
# ### Pearson per device
#
# Different devices may have different sizes, circuits and operating regimes: an
# average taken over the whole fleet can hide behaviours that point in opposite
# directions — and in that case the fleet-level figure is not a summary but an
# artefact of the cancellation.

# %%
t2_rows = []
for d in sorted(r["hwid"] for r in t2_df_hourly.select("hwid").distinct().collect()):
    sub = t2_df_hourly.where(sf.col("hwid") == d)
    rec = {"hwid": d}
    for c in t2_LOAD_COLS + ["load_avg"]:
        try:
            rec[c] = sub.stat.corr(c, t2_TEMP_COL)
        except Exception:
            rec[c] = None
    t2_rows.append(rec)
    vals = "  ".join(f"{k}={v:+.3f}" if isinstance(v, float) else f"{k}=n/a"
                     for k, v in rec.items() if k != "hwid")
    print(f"  {d}:  {vals}")

t2_pdf_corr = pd.DataFrame(t2_rows)
# Out:
#   SW-065:  S125=+0.691  S181=+0.704  load_avg=+0.767
#   SW-088:  S125=-0.598  S181=-0.274  load_avg=-0.571
#   SW-106:  S125=-0.250  S181=-0.241  load_avg=-0.269
#   SW-115:  S125=-0.294  S181=-0.314  load_avg=-0.313

# %%
# Do the devices agree on the sign? If not, the fleet-level correlation is
# the average of opposing behaviours and must not be read as a summary.
t2_signs = t2_pdf_corr["load_avg"].dropna()
t2_pos = (t2_signs > 0).sum()
t2_neg = (t2_signs < 0).sum()

print(f"Devices with positive correlation: {t2_pos}")
print(f"Devices with negative correlation: {t2_neg}")
if t2_pos and t2_neg:
    print()
    print("WARNING: the devices disagree on the sign. The fleet-level")
    print("coefficient is therefore a cancellation artefact, not a summary:")
    print("the per-device figures are the ones to report.")
# Out:
# Devices with positive correlation: 1
# Devices with negative correlation: 3
#
# WARNING: the devices disagree on the sign. The fleet-level
# coefficient is therefore a cancellation artefact, not a summary:
# the per-device figures are the ones to report.

# %% [markdown]
# ### What the coefficients say
#
# Three devices out of four correlate **negatively** — they load up as it gets
# colder, which is what a heating machine does. SW-065 correlates **positively**,
# and more strongly than any of the others.
#
# When all observations are pooled, these two groups pull the regression line in
# opposite directions and largely cancel each other out. The resulting −0.16
# describes none of the four machines: it is an artefact of mixing populations
# that behave differently, and it disappears as soon as they are separated.
#
# A trend can appear, vanish or reverse depending on whether you look at
# subgroups or at the aggregate. The practical consequence here is that the
# fleet-level figure must not be reported as the result of this task. The four
# per-device figures are.

# %%
# Pearson coefficients per device, at a glance
fig, ax = plt.subplots(figsize=(8, 4))
t2_x = range(len(t2_pdf_corr))
bar_w = 0.25
for i, c in enumerate(t2_LOAD_COLS + ["load_avg"]):
    ax.bar([p + i * bar_w for p in t2_x], t2_pdf_corr[c].fillna(0),
           width=bar_w, label=c)
ax.set_xticks([p + bar_w for p in t2_x])
ax.set_xticklabels(t2_pdf_corr["hwid"])
ax.axhline(0, color="black", linewidth=0.8)
ax.set_ylabel(f"Pearson r  (vs {t2_TEMP_COL})")
ax.set_title("Load-temperature correlation per device")
ax.legend()
ax.grid(alpha=0.3, axis="y")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Spearman correlation
#
# Spearman is Pearson computed on **ranks** rather than raw values: it captures
# any *monotonic* relationship, linear or not. A Spearman clearly larger in
# magnitude than Pearson signals a strong but curved relationship.
#
# Spark does not expose Spearman on `stat.corr`, but it follows from applying
# Pearson to the rank-transformed columns via `percent_rank()`.
#
# Note that these window functions have no `partitionBy`, so Spark moves all rows
# to a single partition and warns about it. That is expected for a global rank
# and harmless here, since the hourly table holds only a few thousand rows — it
# would not be acceptable on the raw dataset.

# %%
t2_df_ok = t2_df_hourly.where(
    sf.col("load_avg").isNotNull() & sf.col(t2_TEMP_COL).isNotNull()
)

t2_df_ranked = (
    t2_df_ok.withColumn("rank_load", sf.percent_rank().over(Window.orderBy("load_avg")))
            .withColumn("rank_temp", sf.percent_rank().over(Window.orderBy(t2_TEMP_COL)))
)

t2_spearman = t2_df_ranked.stat.corr("rank_load", "rank_temp")
print(f"Spearman  load_avg vs {t2_TEMP_COL}: {t2_spearman:+.4f}")
print(f"Pearson   load_avg vs {t2_TEMP_COL}: {t2_corr_hour['load_avg']:+.4f}")
# Out:
# 26/09/13 15:49:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/09/13 15:49:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/09/13 15:49:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/09/13 15:49:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/09/13 15:49:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/09/13 15:49:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/09/13 15:49:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/09/13 15:49:50 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/09/13 15:49:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/09/13 15:49:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/09/13 15:49:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/09/13 15:49:51 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# Spearman  load_avg vs S41: -0.0906
# Pearson   load_avg vs S41: -0.1569

# %% [markdown]
# Spearman comes out **lower in magnitude than Pearson**, which is informative
# in itself. Spearman detects any monotonic association, curved or not, so a
# value near zero rules out the explanation *"the relationship is strong but
# bends"*. What remains is a relationship that does not run in one direction at
# all — which the next section confirms.

# %% [markdown]
# ## 9. Mean load per temperature bin
#
# This is the key step of the analysis. Grouping observations into temperature
# intervals and averaging the load within each makes a **non-monotonic**
# relationship visible: if load rises both in the cold and in the heat, the
# profile takes a U shape that no linear correlation coefficient could reveal.
#
# Bins with few samples are discarded, as their mean is unreliable. The first
# table mixes all four devices — each bin averages over every device that
# recorded a measurement in that temperature range — while the second keeps them
# separate, since the previous section showed they may not behave alike.

# %%
t2_BIN_WIDTH = 2.0      # degrees Celsius
t2_MIN_COUNT = 50       # minimum samples for a bin to be trusted

t2_df_binned = t2_df_wide.where(
    sf.col(t2_TEMP_COL).isNotNull() & sf.col("load_avg").isNotNull()
).withColumn(
    "temp_bin", sf.floor(sf.col(t2_TEMP_COL) / t2_BIN_WIDTH) * t2_BIN_WIDTH
)

t2_profile = (
    t2_df_binned.groupBy("temp_bin")
                .agg(sf.mean("load_avg").alias("mean_load"),
                     sf.stddev("load_avg").alias("std_dev"),
                     sf.count("*").alias("n"))
                .where(sf.col("n") >= t2_MIN_COUNT)
                .orderBy("temp_bin")
)

# toPandas() is safe here: the profile has a few dozen rows
t2_pdf_profile = t2_profile.toPandas()
print(f"Temperature range covered: "
      f"{t2_pdf_profile['temp_bin'].min():.0f} to "
      f"{t2_pdf_profile['temp_bin'].max():.0f} deg C")
t2_pdf_profile.head(20)
# Out:
# Temperature range covered: -12 to 30 deg C
#     temp_bin  mean_load    std_dev      n
# 0      -12.0  42.555000  16.004007    250
# 1      -10.0  47.319246  14.327007   1473
# 2       -8.0  49.088288  18.543727   2220
# 3       -6.0  38.123459  23.221876   3570
# 4       -4.0  24.353848  27.161934   4184
# 5       -2.0  23.115585  30.235080  10134
# 6        0.0  21.876766  32.176213  31610
# 7        2.0  22.068865  33.344726  55747
# 8        4.0  24.216093  31.851209  65284
# 9        6.0  20.169241  25.996133  66913
# 10       8.0  19.497461  25.145231  86065
# 11      10.0  22.628772  21.188447  73399
# 12      12.0  18.451052  19.526038  74442
# 13      14.0  15.751369  19.300760  57822
# 14      16.0  15.141490  18.896871  44078
# 15      18.0  10.845812  17.898724  33738
# 16      20.0  10.227546  18.542137  23251
# 17      22.0  11.227403  19.755136  17137
# 18      24.0  16.591349  23.930831  10698
# 19      26.0  28.595325  28.053602   4260

# %% [markdown]
# This table mixes all four devices: each bin averages over every device that
# recorded a measurement in that temperature range.

# %%
# Same profile, per device
t2_prof_dev = (
    t2_df_binned.groupBy("hwid", "temp_bin")
                .agg(sf.mean("load_avg").alias("mean_load"),
                     sf.count("*").alias("n"))
                .where(sf.col("n") >= t2_MIN_COUNT)
                .orderBy("hwid", "temp_bin")
                .toPandas()
)
t2_prof_dev.head()
# Out:
#      hwid  temp_bin  mean_load      n
# 0  SW-065      -6.0   0.000000    117
# 1  SW-065      -4.0   0.000000   1237
# 2  SW-065      -2.0   0.936236   3215
# 3  SW-065       0.0   0.928146  11760
# 4  SW-065       2.0   1.983129  16300

# %% [markdown]
# The error bars are the **standard deviation inside each bin**: how spread out
# the individual measurements are around the mean. They do not shrink when a bin
# has more data, because they describe the data, not the precision of the mean.
#
# They are widest in the mild range because those bins contain both idle
# machines at 0% and fully loaded ones near 100%: the mean sits between two
# groups rather than describing a typical value.

# %%
# Load profile vs temperature, all four devices pooled together
# (groupBy on temp_bin only - the per-device breakdown is the next plot).
plt.figure(figsize=(10, 5))
plt.errorbar(t2_pdf_profile["temp_bin"], t2_pdf_profile["mean_load"],
             yerr=t2_pdf_profile["std_dev"], marker="o", capsize=3,
             color="steelblue", ecolor="lightsteelblue", linewidth=2)
plt.xlabel(f"External temperature ({t2_BIN_WIDTH:g} °C bins)")
plt.ylabel("Mean load (%)")
plt.title("Device load vs external temperature — all four devices")
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# The error bars above say nothing about how much data each point rests on — a
# bin with 200 measurements and one with 80 000 can have identical bars. This
# plot supplies the missing piece: the coldest and warmest bins are supported by
# far fewer observations than the mild ones, so the ends of the U are the less
# reliable part of the curve.

# %%
# Observations per bin: shows where the dataset is actually populated
plt.figure(figsize=(10, 3))
plt.bar(t2_pdf_profile["temp_bin"], t2_pdf_profile["n"],
        width=t2_BIN_WIDTH * 0.9, color="lightslategray")
plt.xlabel("External temperature (°C)")
plt.ylabel("Observations")
plt.title("Statistical coverage per temperature bin")
plt.grid(alpha=0.3, axis="y")
plt.tight_layout()
plt.show()

# %%
# Per-device profile: this is where opposite behaviours become visible
plt.figure(figsize=(10, 5))
for d, g in t2_prof_dev.groupby("hwid"):
    plt.plot(g["temp_bin"], g["mean_load"], marker="o", label=d)
plt.xlabel(f"External temperature ({t2_BIN_WIDTH:g} °C bins)")
plt.ylabel("Mean load (%)")
plt.title("Load vs temperature, per device")
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### The relationship is U-shaped
#
# | Temperature | Mean load |
# |---|---|
# | −8 °C | 49.1% |
# | −2 °C | 23.1% |
# | 8 °C | 19.5% |
# | **20 °C** | **10.2%** ← minimum |
# | 26 °C | 28.6% |
# | 30 °C | 42.2% |
#
# Load falls steadily from the cold extreme to a minimum around 18–20 °C, then
# climbs again, reaching at 30 °C roughly the level it had at −8 °C.
#
# A linear coefficient computed on a symmetric U measures the average slope,
# which is near zero by construction. **The conclusion is not "there is no
# correlation" but "there is no linear correlation"**, and that distinction is
# the whole point of computing the binned profile rather than stopping at
# Pearson.
#
# The physics behind each branch is the same. A reversible heat pump moves heat
# across a temperature gap, and compressor work scales with the size of that
# gap: when the outside air sits near the indoor set-point there is little to
# move, and the further it drifts in either direction the harder the compressors
# work. The position of the minimum is itself informative, since 18–20 °C is
# plausibly close to the set-point of the buildings served.
#
# **But the pooled U is not the behaviour of a typical machine.** The per-device
# profiles show that the devices cover different branches of it: SW-088 and
# SW-115 produce the cold side and their load collapses towards 20 °C, SW-065
# contributes almost only to the warm side because below 4 °C it is switched
# off, and only SW-106 traces both branches on its own. The aggregate curve
# therefore reflects the composition of the fleet as much as any single
# machine's response, and each branch rests mostly on a different subset of
# devices.
#
# Both branches are measured rather than extrapolated, since the data spans
# −11 °C to 34 °C. The warm branch nevertheless rests on far fewer observations
# (4 260 minutes in the 26 °C bin against 86 065 at 8 °C), so it is the less
# firmly established of the two.

# %% [markdown]
# ### Switching on, or working harder?
#
# Mean load conflates two things a device can do when it needs more capacity:
# run more of the time, or run harder while it is on. The two separate exactly,
# since the load is zero whenever the device is off:
# $$\text{mean load} \;=\; \text{fraction of time running} \;\times\; \text{mean load while running}$$

# %%
t2_activity = (
    t2_df_binned.groupBy("hwid", "temp_bin")
                .agg(sf.mean(sf.when(sf.col("load_avg") > 0, 1.0).otherwise(0.0))
                       .alias("active_fraction"),
                     sf.mean("load_avg").alias("mean_load_all"),
                     # mean load computed over running minutes only
                     sf.mean(sf.when(sf.col("load_avg") > 0, sf.col("load_avg")))
                       .alias("mean_load_running"),
                     sf.count("*").alias("n"))
                .where(sf.col("n") >= t2_MIN_COUNT)
                .orderBy("hwid", "temp_bin")
                .toPandas()
)
t2_activity.head(10).round(3)
# Out:
#      hwid  temp_bin  active_fraction  mean_load_all  mean_load_running      n
# 0  SW-065      -6.0            0.000          0.000                NaN    117
# 1  SW-065      -4.0            0.000          0.000                NaN   1237
# 2  SW-065      -2.0            0.044          0.936             21.197   3215
# 3  SW-065       0.0            0.034          0.928             27.219  11760
# 4  SW-065       2.0            0.076          1.983             26.174  16300
# 5  SW-065       4.0            0.093          2.761             29.814  15412
# 6  SW-065       6.0            0.196          6.077             30.988  11978
# 7  SW-065       8.0            0.358         11.046             30.890  16405
# 8  SW-065      10.0            0.931         28.769             30.892  15614
# 9  SW-065      12.0            0.979         30.915             31.584  14541

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4.5), sharex=True)

for d, g in t2_activity.groupby("hwid"):
    axes[0].plot(g["temp_bin"], g["active_fraction"], marker="o", label=d)
    axes[1].plot(g["temp_bin"], g["mean_load_running"], marker="o", label=d)

axes[0].set_title("Fraction of time running")
axes[0].set_ylabel("active fraction")
axes[1].set_title("Mean load while running")
axes[1].set_ylabel("mean load (%)")
for a in axes:
    a.set_xlabel("External temperature (°C)")
    a.grid(alpha=0.3)
    a.legend()
plt.tight_layout()
plt.show()

# %%
# Which effect dominates for each device: switching on/off, or modulating?
# The comparison separates "how often it runs" from "how hard it runs".
print("Correlations below are computed across temperature BINS, not raw\n"
      "minutes: n is the number of bins that passed the MIN_COUNT filter.\n")
print(f"{'device':8s} {'corr(active_frac, T)':>22s} {'corr(load|running, T)':>23s} {'n bins':>8s}")
for d, g in t2_activity.groupby("hwid"):
    g2 = g.dropna(subset=["mean_load_running"])
    c_act = g["active_fraction"].corr(g["temp_bin"])
    c_run = g2["mean_load_running"].corr(g2["temp_bin"]) if len(g2) > 2 else float("nan")
    print(f"{d:8s} {c_act:>22.3f} {c_run:>23.3f} {len(g):>8d}")

print()
print("Read the two columns against each other:")
print("  strong in column 1, weak in column 2 -> the device turns ON/OFF with")
print("     temperature; the apparent load correlation is a duty-cycle effect")
print("  weak in column 1, strong in column 2 -> the device runs either way and")
print("     genuinely modulates its load with temperature")
# Out:
# Correlations below are computed across temperature BINS, not raw
# minutes: n is the number of bins that passed the MIN_COUNT filter.
#
# device     corr(active_frac, T)   corr(load|running, T)   n bins
# SW-065                    0.922                   0.531       15
# SW-088                   -0.925                  -0.640       16
# SW-106                   -0.605                   0.848       15
# SW-115                   -0.890                  -0.818       20
#
# Read the two columns against each other:
#   strong in column 1, weak in column 2 -> the device turns ON/OFF with
#      temperature; the apparent load correlation is a duty-cycle effect
#   weak in column 1, strong in column 2 -> the device runs either way and
#      genuinely modulates its load with temperature

# %% [markdown]
# ### Three behaviours, not one
#
#
# | Device | Active fraction (range) | Load while running (range) |
# |---|---|---|
# | SW-065 | 0.00 → 0.99 | 21 → 32% (10 points) |
# | SW-088 | 0.01 → 0.97 | 26 → 65% (39 points) |
# | SW-106 | 0.33 → 1.00 | 36 → 53% (17 points) |
# | SW-115 | 0.05 → 0.99 | 25 → 58% (34 points) |
#
# **SW-065's load does not respond to temperature at all.** Its duty cycle
# swings across the entire range (never running below −4 °C, running over 97% of
# the time above 10 °C) while the load it draws when running stays near 30%
# whatever the weather. Its strong positive correlation is therefore *entirely*
# a duty-cycle effect: the machine is simply switched off in cold weather rather
# than working in reverse. This is what a cooling-only unit would look like, and
# reading `S1` (Unit Mode) would confirm or refute it (section 13).
#
# **SW-088 and SW-115 use both mechanisms in the same direction**: they run more
# often *and* harder as it gets colder. These are the clearest heating-dominated
# machines.
#
# **SW-106 is the composite case.** Its duty cycle falls with temperature (99%
# of the time near 5 °C, 33% near 20 °C) while the load it draws when running
# *rises* (36% in the cold, 53% at 30 °C). The two effects partly cancel, which
# is why its overall coefficient (−0.27) is the weakest in the fleet, not
# because the relationship is weak, but because it is the sum of two opposing
# ones. Without this decomposition the device would have been written off as
# uncorrelated.

# %% [markdown]
# ## 10. Circuit 1 vs circuit 2
#
# The assignment names `S125` and `S181` separately, so it is worth asking
# whether the two circuits behave alike. One panel per device rather than a
# pooled curve: with one machine running the profile backwards, both circuit
# averages would flatten the same way and look similar for the wrong reason.

# %%
# Circuit 1 vs circuit 2, one panel per device.
# Pooling the devices would hide the answer: with one device running the curve
# backwards, both circuit averages get flattened the same way and end up
# looking alike for the wrong reason.
t2_circ = (
    t2_df_wide.where(sf.col(t2_TEMP_COL).isNotNull())
              .withColumn("temp_bin",
                          sf.floor(sf.col(t2_TEMP_COL) / t2_BIN_WIDTH) * t2_BIN_WIDTH)
              .groupBy("hwid", "temp_bin")
              .agg(*[sf.mean(c).alias(c) for c in t2_LOAD_COLS],
                   sf.count("*").alias("n"))
              .where(sf.col("n") >= t2_MIN_COUNT)
              .orderBy("hwid", "temp_bin")
              .toPandas()
)

t2_dev_list = sorted(t2_circ["hwid"].unique())
fig, axes = plt.subplots(1, len(t2_dev_list), figsize=(4 * len(t2_dev_list), 4),
                         sharey=True)
if len(t2_dev_list) == 1:
    axes = [axes]

for ax, d in zip(axes, t2_dev_list):
    g = t2_circ[t2_circ["hwid"] == d]
    for c, colour in zip(t2_LOAD_COLS, ["darkorange", "seagreen"]):
        ax.plot(g["temp_bin"], g[c], marker="o", markersize=4, color=colour,
                label=f"{c} (circ. {t2_LOAD_COLS.index(c) + 1})")
    ax.set_title(d)
    ax.set_xlabel("External temp (°C)")
    ax.grid(alpha=0.3)

axes[0].set_ylabel("Mean load (%)")
axes[0].legend(fontsize=8)
plt.suptitle("Circuit 1 vs circuit 2, per device")
plt.tight_layout()
plt.show()

# %%
# Do the two circuits track each other? The answer depends on which minutes
# are counted, so all three sets are computed and compared.
#
#   all minutes        : 54% have both circuits at zero, so the coefficient
#                        largely measures "they switch off together"
#   device running     : at least one circuit working
#   both running       : the only set that isolates coordinated modulation
#
# One groupBy instead of a loop over devices: a per-device loop would launch
# a separate job for every device and column.
t2_corr_sets = {
    "all minutes":    t2_df_wide,
    "device running": t2_df_wide.where(sf.col("load_avg") > 0),
    "both running":   t2_df_wide.where((sf.col(t2_LOAD_COLS[0]) > 0)
                                       & (sf.col(t2_LOAD_COLS[1]) > 0)),
}

t2_circ_corr = None
for t2_label, t2_d in t2_corr_sets.items():
    t2_g = (t2_d.groupBy("hwid")
                .agg(sf.corr(*t2_LOAD_COLS).alias(t2_label),
                     sf.count("*").alias(f"n ({t2_label})"))
                .toPandas()
                .set_index("hwid"))
    t2_circ_corr = t2_g if t2_circ_corr is None else t2_circ_corr.join(t2_g)

print("corr(S125, S181) per device, over three different sets of minutes")
print(t2_circ_corr[list(t2_corr_sets)].round(3).to_string())
print()
print("row counts")
print(t2_circ_corr[[f"n ({k})" for k in t2_corr_sets]].to_string())
# Out:
# corr(S125, S181) per device, over three different sets of minutes
#         all minutes  device running  both running
# hwid
# SW-088        0.333          -0.157         0.504
# SW-106        0.575           0.058         0.264
# SW-065        0.398          -0.329        -0.072
# SW-115        0.677           0.257         0.602
#
# row counts
#         n (all minutes)  n (device running)  n (both running)
# hwid
# SW-088           191997               71085             19174
# SW-106           105879               68624             42097
# SW-065           136288               68914             30171
# SW-115           237687              102891             56620

# %% [markdown]
# Which minutes are counted changes the answer completely.
#
# | Device | all minutes | device running | both running |
# |---|---|---|---|
# | SW-088 | 0.333 | **−0.157** | 0.504 |
# | SW-106 | 0.575 | 0.058 | 0.264 |
# | SW-065 | 0.398 | **−0.329** | −0.072 |
# | SW-115 | 0.677 | 0.257 | 0.602 |
#
# The first column is largely an artefact: 54% of minutes have both circuits at
# zero, so what it mostly measures is that the circuits switch off together.
#
# Once the idle minutes are dropped, three devices out of four fall to zero or
# turn **negative**. A negative coefficient means the circuits **alternate**:
# one works while the other rests, which is how a controller spreads running
# hours across components. Positive staging appears only in the third column,
# when both are on and extra capacity is genuinely needed.
#
# Two things to keep in mind reading the table. For SW-088 the third column
# covers October to December only, since circuit 2 stops in January, so it is
# not directly comparable with the others. And the row counts differ by a factor
# of three between devices, so the columns do not all rest on equally many
# observations.

# %% [markdown]
# ### Do the circuits diverge over time?
#
# The correlations above describe the whole period at once, so they cannot tell
# a fixed imbalance from something that changed partway through.
#
# The time axis can: a constant gap across all six months points to design or
# control, a step change at a date points to an event.

# %%
# Weekly behaviour of each circuit: mean load when running, and how often it
# runs. A fault shows up as a step change at a date, not as a constant offset.
t2_weekly = (
    t2_df_wide
    .withColumn("week", sf.date_trunc("week", sf.col("timestamp_bucket")))
    .groupBy("hwid", "week")
    .agg(*[sf.mean(sf.when(sf.col(c) > 0, sf.col(c))).alias(f"load_{c}")
           for c in t2_LOAD_COLS],
         *[sf.mean(sf.when(sf.col(c) > 0, 1.0).otherwise(0.0)).alias(f"active_{c}")
           for c in t2_LOAD_COLS],
         sf.count("*").alias("n"))
    .where(sf.col("n") >= 1000)          # drop partial weeks at the edges
    .orderBy("hwid", "week")
    .toPandas()
)

t2_devs = sorted(t2_weekly["hwid"].unique())
fig, axes = plt.subplots(2, len(t2_devs), figsize=(4 * len(t2_devs), 7), sharex=True)

for j, d in enumerate(t2_devs):
    g = t2_weekly[t2_weekly["hwid"] == d]
    for c, colour in zip(t2_LOAD_COLS, ["darkorange", "seagreen"]):
        axes[0, j].plot(g["week"], g[f"load_{c}"], marker=".", color=colour, label=c)
        axes[1, j].plot(g["week"], g[f"active_{c}"], marker=".", color=colour, label=c)
    axes[0, j].set_title(d)
    axes[1, j].tick_params(axis="x", rotation=45)
    for a in (axes[0, j], axes[1, j]):
        a.grid(alpha=0.3)

axes[0, 0].set_ylabel("mean load when running (%)")
axes[1, 0].set_ylabel("fraction of time running")
axes[0, 0].legend(fontsize=8)
plt.suptitle("Circuit behaviour over time, per device")
plt.tight_layout()
plt.show()

# %%
# Is the gap between circuits stable, or does it move? A large spread in the
# monthly gap would indicate a change of regime rather than a fixed imbalance.
t2_gap = t2_weekly.copy()
t2_gap["gap"] = t2_gap[f"load_{t2_LOAD_COLS[0]}"] - t2_gap[f"load_{t2_LOAD_COLS[1]}"]

print(f"{'device':8s} {'mean gap':>10s} {'std':>8s} {'min':>8s} {'max':>8s}")
for d in t2_devs:
    g = t2_gap[t2_gap["hwid"] == d]["gap"].dropna()
    if len(g):
        print(f"{d:8s} {g.mean():>9.1f}pp {g.std():>7.1f} {g.min():>7.1f} {g.max():>7.1f}")

print()
print("A stable non-zero mean gap means one circuit systematically carries more")
print("of the load: staging or control, not a fault. A gap that shifts over the")
print("period would be the signature of something changing in the machine.")
# Out:
# device     mean gap      std      min      max
# SW-065         0.2pp     1.0    -1.4     2.2
# SW-088        -0.3pp    12.7   -30.4    29.4
# SW-106        -0.3pp     3.1    -8.6     5.0
# SW-115        -0.4pp     2.3    -4.3     4.2
#
# A stable non-zero mean gap means one circuit systematically carries more
# of the load: staging or control, not a fault. A gap that shifts over the
# period would be the signature of something changing in the machine.

# %% [markdown]
# ### What the weekly profiles show
#
# **SW-088 loses circuit 2 in early January.** The green line follows the orange
# until the first week of 2021, then drops to zero and never recovers, while
# circuit 1 keeps running for the remaining three months and works harder than
# before — its load rises from around 55% to 60–85%. Two isolated green points
# appear afterwards and nothing else.
#
# This is a step change at a date, not a constant offset, and it is what a fault
# looks like. It also explains the finding that prompted this section: the two
# circuits of SW-088 correlate differently with temperature (−0.60 against
# −0.27) not because they are staged differently, but because circuit 2 only has
# data for half the period.
#
# The gap statistics say the same thing numerically: SW-088 shows a standard
# deviation of 12.7 percentage points between the circuits, swinging from −30 to
# +29, against 1.0 to 3.1 for the other three devices.
#
# **SW-065 shuts down entirely in early December.** Both circuits stop in the
# same week and neither restarts. Stopping together points to the machine being
# switched off rather than to a component failing, and it fits the cooling
# hypothesis: the device ran through October and November, the mild part of the
# period, and was off for the winter.
#
# This carries a caveat for the correlation reported earlier. SW-065's positive
# correlation with temperature is confounded with time — the device was on
# during the warm months and off during the cold ones — so it may follow a
# seasonal schedule rather than respond to temperature itself.
#
# **SW-106 and SW-115 behave normally**, with the two circuits tracking each
# other across the whole period.

# %% [markdown]
# ## 11. Sizing analysis
# The assignment notes that the loading percentage *"can indicate issues related
# to under-dimensioned or over-dimensioned devices"*. This section follows that
# up: it is background to the task, not part of the objective, which is about
# correlations with temperature.
#
# A device often running near **100%** has no spare capacity at peak demand and
# is likely **too small** for the plant it serves. One that stays at **low**
# values is likely **too large**: much of the installed capacity is never used.
#
# We look at load percentiles and at time spent in the extreme bands, counting
# only the minutes the device is actually running. The 90% and 30% thresholds
# are ours, not the manufacturer's: they rank the devices against each other,
# they certify nothing.

# %%
t2_HIGH_LOAD = 90       # % above which the device is near its limit
t2_LOW_LOAD  = 30       # % below which the device is barely loaded

t2_df_active = t2_df_wide.where(sf.col("load_avg") > 0)

t2_sizing = t2_df_active.groupBy("hwid").agg(
    sf.count("*").alias("active_minutes"),
    sf.mean("load_avg").alias("mean_load"),
    sf.expr("percentile_approx(load_avg, 0.5)").alias("median"),
    sf.expr("percentile_approx(load_avg, 0.95)").alias("p95"),
    sf.mean(sf.when(sf.col("load_avg") >= t2_HIGH_LOAD, 1.0).otherwise(0.0)).alias("frac_high"),
    sf.mean(sf.when(sf.col("load_avg") <= t2_LOW_LOAD, 1.0).otherwise(0.0)).alias("frac_low"),
).orderBy("hwid")

t2_pdf_sizing = t2_sizing.toPandas()
t2_pdf_sizing.round(2)
# Out:
#      hwid  active_minutes  mean_load  median    p95  frac_high  frac_low
# 0  SW-065           68914      30.77    30.0   50.0       0.00      0.53
# 1  SW-088           71085      44.70    50.0  100.0       0.07      0.17
# 2  SW-106           68624      40.92    43.0   57.0       0.00      0.37
# 3  SW-115          102891      48.02    50.0  100.0       0.11      0.41

# %%
# Relative reading: rank the devices instead of forcing absolute labels
t2_pdf_sizing = t2_pdf_sizing.sort_values("mean_load", ascending=False)

print(f"{'device':8s} {'mean':>7s} {'median':>7s} {'p95':>7s} "
      f"{'>=' + str(t2_HIGH_LOAD) + '%':>8s} {'<=' + str(t2_LOW_LOAD) + '%':>8s}")
for _, r in t2_pdf_sizing.iterrows():
    print(f"{r['hwid']:8s} {r['mean_load']:6.1f}% {r['median']:6.1f}% "
          f"{r['p95']:6.1f}% {100 * r['frac_high']:7.1f}% {100 * r['frac_low']:7.1f}%")

print()
t2_hi = t2_pdf_sizing.iloc[0]
t2_lo = t2_pdf_sizing.iloc[-1]
print(f"Highest duty cycle: {t2_hi['hwid']} (mean {t2_hi['mean_load']:.1f}%, "
      f"{100 * t2_hi['frac_high']:.1f}% of active time at or above {t2_HIGH_LOAD}%)")
print(f"Lowest duty cycle:  {t2_lo['hwid']} (mean {t2_lo['mean_load']:.1f}%, "
      f"{100 * t2_lo['frac_low']:.1f}% of active time at or below {t2_LOW_LOAD}%)")
# Out:
# device      mean  median     p95    >=90%    <=30%
# SW-115     48.0%   50.0%  100.0%    11.0%    40.8%
# SW-088     44.7%   50.0%  100.0%     6.7%    17.3%
# SW-106     40.9%   43.0%   57.0%     0.5%    36.7%
# SW-065     30.8%   30.0%   50.0%     0.0%    53.0%
#
# Highest duty cycle: SW-115 (mean 48.0%, 11.0% of active time at or above 90%)
# Lowest duty cycle:  SW-065 (mean 30.8%, 53.0% of active time at or below 30%)

# %%
# Load distribution per device (histogram computed in Spark)
t2_BIN_LOAD = 10        # bin width, percentage points

t2_hist = (
    t2_df_active.withColumn("load_bin",
                            sf.floor(sf.col("load_avg") / t2_BIN_LOAD) * t2_BIN_LOAD)
                .groupBy("hwid", "load_bin")
                .count()
                .orderBy("hwid", "load_bin")
                .toPandas()
)

# Normalising to a fraction of time, rather than raw counts, makes devices
# with histories of different length comparable
t2_hist["fraction"] = t2_hist.groupby("hwid")["count"].transform(lambda s: s / s.sum())

fig, ax = plt.subplots(figsize=(10, 5))
t2_devices = sorted(t2_hist["hwid"].unique())
bar_w = t2_BIN_LOAD / (len(t2_devices) + 1)
for i, d in enumerate(t2_devices):
    g = t2_hist[t2_hist["hwid"] == d]
    ax.bar(g["load_bin"] + i * bar_w, g["fraction"], width=bar_w, label=d)
ax.set_xlabel(f"Load ({t2_BIN_LOAD}% bins)")
ax.set_ylabel("Fraction of active time")
ax.set_title("Load distribution per device (active minutes only)")
ax.legend()
ax.grid(alpha=0.3, axis="y")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Two groups, and a hint about capacity control
#
# | Device | Mean | Median | p95 | Time ≥90% | Time ≤30% |
# |---|---|---|---|---|---|
# | SW-115 | 48.0% | 50% | 100% | 11.0% | 40.8% |
# | SW-088 | 44.7% | 50% | 100% | 6.7% | 17.3% |
# | SW-106 | 40.9% | 43% | 57% | 0.5% | 36.7% |
# | SW-065 | 30.8% | 30% | 50% | ~0% | 53.0% |
#
# **SW-115 and SW-088 reach saturation**: p95 at 100%, and 11% and 7% of running
# time above 90% load. Little headroom at peak.
#
# **SW-106 and SW-065 have a 95th percentile of 57% and 50%**, so they exceed
# those levels less than 5% of the time. SW-065 sits below 30% for over half its
# running time, and is idle most of the winter besides.
#
# Two caveats. Reading high load as undersized and low load as oversized is
# standard engineering reasoning, not something the assignment states. And
# excluding idle minutes *understates* over-sizing: a machine that is off half
# the time arguably does not need to run at all.
#
# A third caveat matters more than the other two: the dataset says nothing about
# the plants these machines serve. SW-115 working twice as hard as SW-065 may
# simply mean it serves a larger or more demanding building. If the four were
# comparable the figures would point to uneven sizing, but that premise cannot
# be checked here.
#
# The percentiles also hint at something unrelated to sizing. They land on
# values like 43%, 50% and 57% rather than round numbers, and the four devices
# do not agree on which. Section 12 looks at where those levels come from.

# %% [markdown]
# ## 12. Cross-check: how does capacity actually change?
#
# `load_avg` has been read as delivered power throughout. Whether that reading
# holds depends on how the circuits produce intermediate values, which the
# assignment never states.
#
# **The count has to be done on the raw readings, not on the resampled ones.**
# A minute can contain one to three samples, and averaging them already
# manufactures values the sensor never reported: from three levels alone the
# minute means would take nine. Counting on `t2_df_wide` would therefore prove
# nothing about the hardware. `t2_df_raw` carries what was actually measured.

# %%
# Distinct values in the RAW readings, before any resampling: averaging
# samples within a minute would create intermediate levels that the sensor
# never reported, and the count would be meaningless.
t2_quant = (
    t2_df_raw.where(sf.col("metric").isin(t2_LOAD_COLS))
             .groupBy("hwid")
             .pivot("metric", t2_LOAD_COLS)
             .agg(sf.expr("count(distinct value)"))
             .orderBy("hwid")
             .toPandas()
)
print("Distinct raw capacity values per device and circuit")
print(t2_quant.to_string(index=False))
print()

# How to read the count. Two on/off compressors give three levels if they are
# the same size (0, 50, 100) and four if they are not (0, a, b, 100, with
# a + b = 100). More than four means something modulates.
for _, r in t2_quant.iterrows():
    n_max = max(int(r[c]) for c in t2_LOAD_COLS if r[c] is not None)
    if n_max <= 3:
        verdict = "two on/off compressors, equally sized"
    elif n_max == 4:
        verdict = "two on/off compressors, unequally sized"
    else:
        verdict = "more levels than staging alone can produce: modulation"
    print(f"  {r['hwid']}: {n_max} distinct levels -> {verdict}")
# Out:
# [Stage 425:================================================>        (6 + 1) / 7]
# Distinct raw capacity values per device and circuit
#   hwid  S125  S181
# SW-065     4     4
# SW-088     4     4
# SW-106     4     4
# SW-115     4     4
#
#   SW-065: 4 distinct levels -> two on/off compressors, unequally sized
#   SW-088: 4 distinct levels -> two on/off compressors, unequally sized
#   SW-106: 4 distinct levels -> two on/off compressors, unequally sized
#   SW-115: 4 distinct levels -> two on/off compressors, unequally sized

# %%
# Which values actually occur, and how often. The count matters: a value that
# appears once in 300 000 readings is a sensor glitch, not an operating level,
# and the whole section rests on this list.
t2_MIN_OCCUR = 100        # below this, treat a level as noise

t2_levels = (
    t2_df_raw.where(sf.col("metric").isin(t2_LOAD_COLS))
             .groupBy("hwid", "metric", "value")
             .count()
             .orderBy("hwid", "metric", "value")
             .toPandas()
)

for (d, m), g in t2_levels.groupby(["hwid", "metric"]):
    solid = g[g["count"] >= t2_MIN_OCCUR]
    rare  = g[g["count"] < t2_MIN_OCCUR]
    vals = "  ".join(f"{int(r['value'])}({int(r['count']):,})"
                     for _, r in solid.iterrows())
    print(f"{d} {m}: {vals}")
    if len(rare):
        print(f"{'':16s} rare (<{t2_MIN_OCCUR}): "
              f"{sorted(int(v) for v in rare['value'])}")
print()
print("Values shown as level(occurrences). Anything other than 0, 50 and 100")
print("appearing thousands of times rules out two plain on/off compressors.")
# Out:
# [Stage 444:================================================>        (6 + 1) / 7]
# SW-065 S125: 0(149,340)  40(55,562)  60(6,303)  100(293)
# SW-065 S181: 0(146,623)  40(54,327)  60(6,422)  100(188)
# SW-088 S125: 0(204,684)  34(24,876)  66(47,216)  100(46,264)
# SW-088 S181: 0(274,443)  34(13,041)  66(18,391)  100(10,940)
# SW-106 S125: 0(93,615)  43(59,041)  57(45,474)  100(2,853)
# SW-106 S181: 0(95,524)  43(58,246)  57(40,641)  100(2,635)
# SW-115 S125: 0(235,640)  43(38,824)  57(56,321)  100(23,996)
# SW-115 S181: 0(233,098)  43(38,669)  57(52,744)  100(23,617)
#
# Values shown as level(occurrences). Anything other than 0, 50 and 100
# appearing thousands of times rules out two plain on/off compressors.

# %% [markdown]
# ### Four levels, not a continuum
#
# Each circuit reports exactly **four** values, and they differ by device:
#
# | Device | Levels |
# |---|---|
# | SW-065 | 0, **40**, **60**, 100 |
# | SW-088 | 0, **34**, **66**, 100 |
# | SW-106 | 0, **43**, **57**, 100 |
# | SW-115 | 0, **43**, **57**, 100 |
#
# Every intermediate pair sums to 100. That is **two on/off compressors of
# unequal size**: neither running gives 0, the smaller alone gives its share,
# the larger alone gives the rest, both together give 100. Nothing modulates.
#
# It also explains why 50% never appears as a level. Two equally sized
# compressors would give 0, 50 and 100; these are split 43/57, 34/66 and 40/60,
# so the middle values land elsewhere. The absence of 50 looked like evidence of
# modulation and is instead evidence that the two compressors in a circuit are
# not the same size.
#
# The counts rule out glitches: each intermediate level occurs tens of thousands
# of times.
# `load_avg` still reads as delivered capacity, since 43% really is 43% of what
# the circuit can do. What changes is the mechanism: discrete staging of unequal
# units rather than a compressor varying its speed.
#
# This does not contradict sections 9 and 10. "Modulation" there meant whether
# the load responds to temperature; here it means what values the hardware can
# produce at all. A machine with four discrete levels can still show a smoothly
# varying *average* load, by changing how much time it spends at each level, just
# as a domestic thermostat holds a steady room temperature with a boiler that is
# only ever on or off. `load_avg` averages over two circuits and over thousands
# of minutes, so it takes continuous values even though each individual reading
# does not.

# %% [markdown]
# ## 13. Cross-check: operating modes
#
# The behaviours above were all deduced from load and temperature. The dataset
# carries variables describing what the machines are actually set to do: `S1`
# (Unit Mode), `S2` (Unit Status), `S123` and `S179` (circuit mode).
#
# Two filters are needed for this to be a real check rather than a restatement.
# **Only running minutes**, because a machine that is off cannot change mode, so
# on the full period SW-065 would show a constant code by construction. And
# **the same calendar window for every device**, because SW-065's active minutes
# fall almost entirely in October and November while the others span all six
# months, so a constant code could otherwise just mean that those two months are
# a constant-mode period for everyone.

# %%
# Same pattern as the compressor cross-check: read, resample, pivot.
# These are discrete state codes, so MAX is the right resampling rule —
# averaging mode codes would produce meaningless intermediate values.
t2_MODE_COLS = ["S1", "S2", "S123", "S179"]

t2_df_mode = (
    t2_df_raw.where(sf.col("metric").isin(t2_MODE_COLS))
    .withColumn("timestamp_bucket",
                sf.date_trunc("minute", sf.timestamp_millis(sf.col("when"))))
    .groupBy("timestamp_bucket", "hwid", "metric")
    .agg(sf.max("value").alias("value"))
    .groupBy("timestamp_bucket", "hwid")
    .pivot("metric", t2_MODE_COLS)
    .agg(sf.first("value"))
)

print(f"Rows with mode data: {t2_df_mode.count():,}")
t2_df_mode.show(5)
# Out:
# Rows with mode data: 671,851
# [Stage 460:============================>                            (3 + 3) / 6]
# +-------------------+------+---+---+----+----+
# |   timestamp_bucket|  hwid| S1| S2|S123|S179|
# +-------------------+------+---+---+----+----+
# |2021-01-13 22:19:00|SW-088|  1|  2|   4|   1|
# |2020-10-24 21:20:00|SW-115|  0|  2|   1|   3|
# |2020-10-27 19:10:00|SW-115|  0|  2|   1|   1|
# |2021-02-18 20:28:00|SW-106|  1|  2|   5|NULL|
# |2021-02-21 00:36:00|SW-106|  1|  2|   5|   5|
# +-------------------+------+---+---+----+----+
# only showing top 5 rows

# %%
# Which mode does each device spend its time in? The codes are not documented
# in the assignment, so what matters is whether SW-065 differs from the rest.
for t2_m in t2_MODE_COLS:
    t2_dist = (
        t2_df_mode.where(sf.col(t2_m).isNotNull())
                  .groupBy("hwid", t2_m)
                  .count()
                  .orderBy("hwid", sf.col("count").desc())
                  .toPandas()
    )
    if not len(t2_dist):
        print(f"{t2_m}: no data\n")
        continue
    t2_dist["share"] = t2_dist.groupby("hwid")["count"].transform(lambda s: s / s.sum())
    print(f"--- {t2_m} ---")
    for d, g in t2_dist.groupby("hwid"):
        top = g.head(3)
        desc = "  ".join(f"code {int(r[t2_m])}: {100*r['share']:.0f}%"
                         for _, r in top.iterrows())
        print(f"  {d}: {desc}")
    print()
# Out:
# --- S1 ---
#   SW-065: code 0: 100%
#   SW-088: code 0: 75%  code 1: 25%
#   SW-106: code 1: 53%  code 0: 47%
#   SW-115: code 0: 100%
# --- S2 ---
#   SW-065: code 2: 100%
#   SW-088: code 2: 94%  code 0: 6%  code 3: 1%
#   SW-106: code 2: 95%  code 0: 5%
#   SW-115: code 2: 100%  code 0: 0%  code 3: 0%
# --- S123 ---
#   SW-065: code 1: 100%
#   SW-088: code 4: 76%  code 1: 17%  code 3: 5%
#   SW-106: code 5: 51%  code 3: 24%  code 1: 16%
#   SW-115: code 4: 49%  code 1: 26%  code 7: 8%
# [Stage 523:===============================================>         (5 + 1) / 6]
# --- S179 ---
#   SW-065: code 1: 100%
#   SW-088: code 1: 43%  code 4: 42%  code 5: 13%
#   SW-106: code 5: 51%  code 3: 24%  code 1: 19%
#   SW-115: code 4: 56%  code 1: 25%  code 7: 8%

# %%
# Mode distribution with a double filter: running minutes only, and the same
# calendar window for every device.
#
# Running minutes alone are not enough. SW-065's active minutes fall almost
# entirely in October-November while the others span all six months, so
# "SW-065 is constant" could just mean "October-November is a constant-mode
# period for everyone". Restricting all four to that window removes it.
t2_WINDOW_END = "2020-12-01"

t2_df_mode_active = (
    t2_df_mode.join(
        t2_df_wide.select("hwid", "timestamp_bucket", "load_avg"),
        on=["hwid", "timestamp_bucket"], how="inner")
    .where(sf.col("load_avg") > 0)
)
t2_df_mode_window = t2_df_mode_active.where(
    sf.col("timestamp_bucket") < sf.lit(t2_WINDOW_END).cast("timestamp"))

print(f"active minutes, whole period:      {t2_df_mode_active.count():,}")
print(f"active minutes, Oct-Nov only:      {t2_df_mode_window.count():,}")

print("active minutes per device, Oct-Nov window")
t2_df_mode_window.groupBy("hwid").count().orderBy("hwid").show()

for t2_name, t2_set in [("running minutes, whole period", t2_df_mode_active),
                        ("running minutes, Oct-Nov only", t2_df_mode_window)]:
    print(f"===== {t2_name} =====")
    for t2_m in ["S123", "S179"]:          # the two that discriminate
        t2_dist = (
            t2_set.where(sf.col(t2_m).isNotNull())
                  .groupBy("hwid", t2_m)
                  .count()
                  .orderBy("hwid", sf.col("count").desc())
                  .toPandas()
        )
        if not len(t2_dist):
            print(f"  {t2_m}: no data")
            continue
        t2_dist["share"] = t2_dist.groupby("hwid")["count"].transform(lambda s: s/s.sum())
        print(f"  --- {t2_m} ---")
        for d, g in t2_dist.groupby("hwid"):
            desc = "  ".join(f"code {int(r[t2_m])}: {100*r['share']:.0f}%"
                             for _, r in g.head(3).iterrows())
            print(f"    {d}: {desc}")
    print()
# Out:
# active minutes, whole period:      311,514
# active minutes, Oct-Nov only:      143,730
# active minutes per device, Oct-Nov window
# +------+-----+
# |  hwid|count|
# +------+-----+
# |SW-065|68914|
# |SW-088|14779|
# |SW-106|20090|
# |SW-115|39947|
# +------+-----+
#
# ===== running minutes, whole period =====
#   --- S123 ---
#     SW-065: code 1: 100%
#     SW-088: code 4: 92%  code 3: 3%  code 1: 2%
#     SW-106: code 5: 70%  code 3: 21%  code 1: 4%
#     SW-115: code 4: 78%  code 5: 7%  code 2: 4%
#   --- S179 ---
#     SW-065: code 1: 100%
#     SW-088: code 4: 46%  code 1: 37%  code 5: 15%
#     SW-106: code 5: 70%  code 1: 13%  code 3: 11%
#     SW-115: code 4: 86%  code 5: 4%  code 1: 4%
#
# ===== running minutes, Oct-Nov only =====
#   --- S123 ---
#     SW-065: code 1: 100%
#     SW-088: code 4: 81%  code 3: 13%  code 1: 4%
#     SW-106: code 3: 71%  code 1: 12%  code 4: 8%
#     SW-115: code 4: 82%  code 3: 5%  code 5: 5%
# [Stage 658:=============================================>       (173 + 4) / 200]
#   --- S179 ---
#     SW-065: code 1: 100%
#     SW-088: code 4: 86%  code 1: 6%  code 3: 5%
#     SW-106: code 1: 42%  code 3: 37%  code 4: 12%
#     SW-115: code 4: 92%  code 1: 3%  code 5: 2%

# %% [markdown]
# ### What the mode variables say
#
# `S2` says nothing useful: every device sits at code 2 almost always, so it is
# probably a generic "running" flag. `S1` helps only in part, since SW-065 and
# SW-115 both stay at code 0 throughout.
#
# **The circuit modes discriminate.** Restricted to running minutes in the
# October-November window, where all four devices are active:
#
# | Device | S123 | S179 |
# |---|---|---|
# | SW-065 | code 1: **100%** | code 1: **100%** |
# | SW-088 | code 4: 81% | code 4: 86% |
# | SW-106 | code 3: 71% | code 1: 42%, code 3: 37% |
# | SW-115 | code 4: 82% | code 4: 92% |
#
# SW-065 is the only device that stays on a single code. The double filter is
# what makes this a check rather than a restatement: an idle machine cannot
# change mode, and a single calendar window rules out October-November simply
# being a constant-mode period for everyone.
#
# So the inference holds in the form it can be checked: **SW-065 is the only
# device that does not change operating mode while running.** The assignment
# does not document the codes, so this cannot become "code 1 is cooling"
# outright.
#
# Three caveats. The window is unbalanced: SW-065 contributes 68 914 active
# minutes against SW-088's 14 779. Code 1 is not unique to SW-065, since SW-106
# has it as its dominant `S179` value at 42% — what singles SW-065 out is
# staying on one code exclusively, not which code it is. And SW-106 is the only
# device whose dominant code differs between the two windows (5 over the full
# period, 3 in October-November), which fits it being the one machine that
# traces both branches of the U.

# %% [markdown]
# ## 14. Saving the results
#
# A subtlety about **where** Spark writes. `df.write.parquet("/opt/...")` is
# executed by the *executors*, each writing its own partitions to its **own
# local disk**. Even with `coalesce(1)` the single remaining partition is still
# written by an executor, which may well be running on a worker node where
# `/opt/mapd-project` does not exist — the job then fails with
# `Mkdirs failed to create file:/opt/...`.
#
# There are two correct options:
#
# - write to **S3**, which every node can reach (`s3a://...`);
# - or, for results already small enough to fit in the driver, collect them and
#   write from the **driver** with pandas, which runs on the master.
#
# All the outputs here are aggregates of a few dozen to a few thousand rows, so
# the second option is both simpler and sufficient.

# %%
t2_OUT_DIR = "/opt/mapd-project/results_ad2"
os.makedirs(t2_OUT_DIR, exist_ok=True)

# Written by the driver (pandas), not by the executors: no distributed
# filesystem needed, and the file lands on the master where we can find it.
t2_pdf_profile.to_csv(f"{t2_OUT_DIR}/ad2_temp_profile.csv", index=False)
t2_prof_dev.to_csv(f"{t2_OUT_DIR}/ad2_temp_profile_per_device.csv", index=False)
t2_pdf_corr.to_csv(f"{t2_OUT_DIR}/ad2_correlations.csv", index=False)
t2_pdf_sizing.to_csv(f"{t2_OUT_DIR}/ad2_sizing.csv", index=False)
t2_activity.to_csv(f"{t2_OUT_DIR}/ad2_activity_vs_temperature.csv", index=False)
t2_weekly.to_csv(f"{t2_OUT_DIR}/ad2_circuits_weekly.csv", index=False)

print(f"Results written to {t2_OUT_DIR}/")
for f in ["ad2_temp_profile", "ad2_temp_profile_per_device", "ad2_correlations",
          "ad2_sizing", "ad2_activity_vs_temperature", "ad2_circuits_weekly"]:
    print(f"  {f}.csv")
# Out:
# Results written to /opt/mapd-project/results_ad2/
#   ad2_temp_profile.csv
#   ad2_temp_profile_per_device.csv
#   ad2_correlations.csv
#   ad2_sizing.csv
#   ad2_activity_vs_temperature.csv
#   ad2_circuits_weekly.csv

# %% [markdown]
# ## 15. Conclusions
#
# **One circuit stops during the period.** SW-088's second circuit goes to zero
# in the first week of January 2021 and never comes back, while circuit 1 keeps
# running for the remaining three months at a visibly higher load. The weekly
# profiles show a step change at a date, not a constant offset, and the gap
# between the two circuits swings by 12.7 percentage points against 1.0–3.1 on
# the other devices. Whether the compressor failed, the sensor failed, or the
# circuit was taken out of service cannot be told apart from these data. It also
# explains why SW-088 was the only machine whose circuits correlate differently
# with temperature: circuit 2 simply has data for half the period.
#
# **The pooled correlation is meaningless.** Across all four devices r = −0.16,
# reading as "almost no relationship". Separated, three correlate strongly
# negative and one strongly positive: the pooled figure describes no machine in
# the data.
#
# **The relationship is real but not linear.** The binned profile traces a U,
# minimal around 18–20 °C and rising at both extremes, because compressor work
# scales with the thermal gap in either direction. The devices cover different
# branches of it, though (SW-088 and SW-115 produce the cold side, SW-065 only
# the warm one, and only SW-106 traces both) so the pooled U reflects the
# composition of the fleet rather than the response of a typical machine.
#
# **The devices get there differently.** SW-065 is essentially on/off: idle
# below 4 °C, fixed at ~30% whenever running, so its positive correlation is a
# duty-cycle effect rather than reverse operation. SW-088 and SW-115 run both
# more often and harder as it gets colder. SW-106 does the two in opposite
# directions, which is why its coefficient looks weak while neither trend is.
#
# **Capacity moves in four discrete steps, not continuously.** The raw readings
# take exactly four values per circuit, and the intermediate pair always sums to
# 100: 43/57 on two devices, 34/66 and 40/60 on the others. That is two on/off
# compressors of unequal size, staged. The absence of 50% had looked like
# evidence of modulation and is instead evidence that the two compressors in a
# circuit are not the same size. `load_avg` still reads as delivered capacity,
# since 43% is 43% of nominal, but the mechanism is discrete staging.
# This concerns what the hardware can produce, not whether the load responds to
# temperature: an average over two circuits and thousands of minutes varies
# continuously even when each individual reading does not.
#
# **On sizing**, SW-115 and SW-088 reach full capacity with little headroom at
# peak; SW-106 and SW-065 have a 95th percentile of 57% and 50%. Whether that
# reflects uneven sizing or simply different buildings cannot be decided here,
# since the dataset carries no information about the plants being served.
#
# **The mode variables back up the reading of SW-065** Restricted to running minutes in the
# window where all four devices are active, SW-065 stays on a single circuit
# mode for 100% of the time while the others sit predominantly on different
# codes. The assignment does not document the codes, so this cannot become
# "SW-065 cools" outright, but the difference appears in a variable that played
# no part in the deduction.
#
#
# ### Limitations
#
# The warm branch of the U rests on an order of magnitude fewer observations
# than the cold one.
#
# SW-065's positive correlation is confounded with time: the device ran through
# October and November and was off from December to March, so it may follow a
# seasonal schedule rather than respond to temperature itself. The two are
# indistinguishable in these data.
#
#
# Six months is too short to detect mechanical deterioration, which the
# assignment lists among the things load can reveal. Comparing October against
# March at equal temperature would not isolate wear either: the months differ in
# humidity, solar gain and occupancy.
#
#
# Correlation is not causation. The load also depends on the set-point, on how
# much the building is used, and on maintenance — none of which is in the
# dataset. Some of what looks like a response to temperature could be caused by
# one of these, which happens to change with the season too.

# %% [markdown]
# ## 16. Scaling benchmark
#
# How the pipeline scales cannot be measured from inside the notebook: the
# SparkSession is created once and its resources are fixed for its lifetime. It
# runs as a separate script, `benchmark_ad2.py`, one Spark application per core
# count, with the cluster otherwise idle.
#
# Three phases are timed, following the ones the assignment asks to
# characterise:
#
# | Phase | What it does | Shape |
# |---|---|---|
# | Map-like | read, filter 3 metrics out of ~120, rescale | narrow only, no shuffle |
# | Group-like | minute resampling, pivot, hourly aggregation, per-device correlations | four wide dependencies |
# | Advanced mix | binned profile, duty cycle split, global ordering | different keys, plus one stage that cannot parallelise |
#
# The cluster runs the standalone manager, so the resource cap is
# `spark.cores.max`; `--num-executors` is a YARN flag and would be silently
# ignored.
#
# One caveat on how to read the numbers. Each worker starts one executor, so
# asking for more cores also involves more workers and more total memory: 1 GB
# at one core, 3 GB at six. Cores and memory grow together, which is why the
# memory column is reported alongside the speed-up.

# %%
# Benchmark results, produced offline by benchmark_ad2.py. Loaded rather than
# recomputed: the measurement needs one Spark application per core count, and
# the cluster has to be idle for the timings to mean anything.
import os
from IPython.display import Image, display

t2_BENCH_DIR = os.path.expanduser("~/benchmark_ad2")

try:
    t2_bench = pd.read_csv(f"{t2_BENCH_DIR}/benchmark_summary.csv")
    cols = ["task_name", "cores", "executors", "total_exec_memory_gb",
            "wall_time_mean", "speedup", "efficiency"]
    print(t2_bench[cols].round(3).to_string(index=False))

    for p in ["plot1_speedup.png", "plot2_efficiency.png",
              "plot3_shuffle_partitions.png", "plot4_time_breakdown.png"]:
        f = f"{t2_BENCH_DIR}/benchmark_plots/{p}"
        if os.path.exists(f):
            display(Image(filename=f))
except FileNotFoundError:
    print(f"{t2_BENCH_DIR}/benchmark_summary.csv not found — "
          "run benchmark_ad2.py first.")
# Out:
#                             task_name  cores  executors  total_exec_memory_gb  wall_time_mean  speedup  efficiency
#     1. Map-like (ingestion + rescale)      1          1                   1.0          10.815    1.000       1.000
#     1. Map-like (ingestion + rescale)      2          1                   1.0           6.839    1.581       0.791
#     1. Map-like (ingestion + rescale)      4          2                   2.0           3.291    3.286       0.822
#     1. Map-like (ingestion + rescale)      6          3                   3.0           3.210    3.369       0.562
# 2. Group-like (aggregate + correlate)      1          1                   1.0          31.253    1.000       1.000
# 2. Group-like (aggregate + correlate)      2          1                   1.0          17.756    1.760       0.880
# 2. Group-like (aggregate + correlate)      4          2                   2.0          10.249    3.050       0.762
# 2. Group-like (aggregate + correlate)      6          3                   3.0           8.829    3.540       0.590
#    3. Advanced mix (profile + window)      1          1                   1.0           2.627    1.000       1.000
#    3. Advanced mix (profile + window)      2          1                   1.0           1.539    1.707       0.853
#    3. Advanced mix (profile + window)      4          2                   2.0           1.243    2.114       0.528
#    3. Advanced mix (profile + window)      6          3                   3.0           1.182    2.223       0.370

# %% [markdown]
# ### What the curves show
#
# | Phase | speed-up 1→6 cores | efficiency at 6 |
# |---|---|---|
# | Map-like | 3.37× | 0.56 |
# | Group-like | 3.54× | 0.59 |
# | Advanced mix | 2.22× | 0.37 |
#
# The order matches what the shape of each phase predicts. The mix scales worst
# because it contains a global ordering with no `partitionBy`: Spark funnels
# every row into a single partition there, and that stage cannot use more than
# one core however many are allocated.
#
# Efficiency falls for all three as cores are added, and the knee sits around
# four: going from four to six cores buys almost nothing (3.29s to 3.21s on the
# map-like phase). Past that point the coordination overhead absorbs the gain.
# This is Amdahl's law in the measurement rather than in the abstract.
#
# Shuffle partitions were tuned separately at six cores, and runtime grows
# monotonically with the partition count: 30.1s at 6, 36.2s at 200. With six
# cores available, six partitions already saturate them, and every partition
# beyond that is scheduling overhead with no hardware to run on. The task count
# confirms it: 200 partitions schedule 1 944 tasks against 194 at six, for 20%
# more wall-clock time.

# %% [markdown]
# ## 17. Closing the session

# %%
spark.stop()
